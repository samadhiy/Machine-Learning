# %% [markdown]
# <a href="https://colab.research.google.com/github/samadhiy/Machine-Learning/blob/main/Lab_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Lab Sheet 2 - Logistic Regression

# %% [markdown]
# 22UG2-0013

# %% [markdown]
# Step 1: Import Required Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Step 2: Upload & Load the Dataset (Colab)

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-93103d91-83ee-43b8-81a8-ed379a39f2ff" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-93103d91-83ee-43b8-81a8-ed379a39f2ff">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
dataset = pd.read_csv('Social_Network_Ads.csv')
dataset.head()
# Out:
#    Age  EstimatedSalary  Purchased
# 0   56            23392          0
# 1   46            45535          0
# 2   32           128569          1
# 3   25            67256          0
# 4   38           104135          1

# %% [markdown]
# Step 3: Dataset Information

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Age              100 non-null    int64
#  1   EstimatedSalary  100 non-null    int64
#  2   Purchased        100 non-null    int64
# dtypes: int64(3)
# memory usage: 2.5 KB

# %% [markdown]
# Step 4: Select Features and Target

# %%
X = dataset[['Age', 'EstimatedSalary']]
y = dataset['Purchased']

# %% [markdown]
# Step 5: Split Dataset into Training & Testing Sets

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=0
)

# %% [markdown]
# Step 6: Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# Step 7: Train Logistic Regression Model

# %%
from sklearn.linear_model import LogisticRegression

classifier = LogisticRegression(random_state=0)
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=0)

# %% [markdown]
# Step 8: Predict Test Results

# %%
y_pred = classifier.predict(X_test)

# %% [markdown]
# Step 9: Accuracy Score

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_test, y_pred)
accuracy
# Out:
# 0.84

# %% [markdown]
# Step 10: Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[ 9,  4],
#        [ 0, 12]])

# %% [markdown]
# Step 11: Predict Purchase for a New User

# %%
new_user = sc.transform([[30, 50000]])  # Age = 30, Salary = 50000
prediction = classifier.predict(new_user)
prediction
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([0])

# %% [markdown]
# Step 12: Probability of Purchase

# %%
probability = classifier.predict_proba(new_user)
probability
# Out:
# array([[0.70577698, 0.29422302]])
